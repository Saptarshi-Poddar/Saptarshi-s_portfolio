# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px



import warnings
warnings.filterwarnings('ignore')

plt.style.use("fivethirtyeight")    # FOR Styling in matplotlib
# %matplotlib inline

pd.set_option('display.max_columns', 30)

# %%
df = pd.read_csv(r"C:\Users\sapta\OneDrive\Desktop\Data Science LAB\Machine Learning\EDA\kidney_disease.csv")

# %%
df
# Out:
#       id   age    bp     sg   al   su     rbc        pc         pcc  \
# 0      0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent
# 1      1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent
# 2      2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent
# 3      3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present
# 4      4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent
# ..   ...   ...   ...    ...  ...  ...     ...       ...         ...
# 395  395  55.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0  normal    normal  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0  normal    normal  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0  normal    normal  notpresent
#
#              ba    bgr    bu   sc    sod  pot  hemo pcv    wc   rc  htn   dm  \
# ...

# %%
df.shape
# Out:
# (400, 26)

# %%
df.head()
# Out:
#    id   age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0   0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 1   1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 2   2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3   3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4   4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
#
#      bgr    bu   sc    sod  pot  hemo pcv    wc   rc  htn   dm cad appet   pe  \
# 0  121.0  36.0  1.2    NaN  NaN  15.4  44  7800  5.2  yes  yes  no  good   no
# 1    NaN  18.0  0.8    NaN  NaN  11.3  38  6000  NaN   no   no  no  good   no
# 2  423.0  53.0  1.8    NaN  NaN   9.6  31  7500  NaN   no  yes  no  poor   no
# 3  117.0  56.0  3.8  111.0  2.5  11.2  32  6700  3.9  yes   no  no  poor  yes
# 4  106.0  26.0  1.4    NaN  NaN  11.6  35  7300  4.6   no   no  no  good   no
#
#    ane classification
# ...

# %%
df.sample()
# Out:
#     id   age    bp  sg  al  su  rbc   pc         pcc          ba   bgr     bu  \
# 50  50  53.0  60.0 NaN NaN NaN  NaN  NaN  notpresent  notpresent  91.0  114.0
#
#       sc    sod  pot  hemo pcv     wc   rc  htn   dm cad appet   pe  ane  \
# 50  3.25  142.0  4.3   8.6  28  11000  3.8  yes  yes  no  poor  yes  yes
#
#    classification
# 50            ckd

# %%
df.sample()
# Out:
#     id   age     bp  sg   al   su  rbc        pc         pcc          ba  \
# 99  99  56.0  180.0 NaN  0.0  4.0  NaN  abnormal  notpresent  notpresent
#
#       bgr    bu   sc    sod  pot  hemo pcv     wc   rc  htn   dm cad appet  \
# 99  298.0  24.0  1.2  139.0  3.9  11.2  32  10400  4.2  yes  yes  no  poor
#
#      pe ane classification
# 99  yes  no            ckd

# %%
df.tail()
# Out:
#       id   age    bp     sg   al   su     rbc      pc         pcc          ba  \
# 395  395  55.0  80.0  1.020  0.0  0.0  normal  normal  notpresent  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0  normal  normal  notpresent  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0  normal  normal  notpresent  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0  normal  normal  notpresent  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0  normal  normal  notpresent  notpresent
#
#        bgr    bu   sc    sod  pot  hemo pcv    wc   rc htn  dm cad appet  pe  \
# 395  140.0  49.0  0.5  150.0  4.9  15.7  47  6700  4.9  no  no  no  good  no
# 396   75.0  31.0  1.2  141.0  3.5  16.5  54  7800  6.2  no  no  no  good  no
# 397  100.0  26.0  0.6  137.0  4.4  15.8  49  6600  5.4  no  no  no  good  no
# 398  114.0  50.0  1.0  135.0  4.9  14.2  51  7200  5.9  no  no  no  good  no
# 399  131.0  18.0  1.1  141.0  3.5  15.8  53  6800  6.1  no  no  no  good  no
#
#     ane classification
# ...

# %%
df.dtypes
# Out:
# id                  int64
# age               float64
# bp                float64
# sg                float64
# al                float64
# su                float64
# rbc                object
# pc                 object
# pcc                object
# ba                 object
# bgr               float64
# bu                float64
# sc                float64
# sod               float64
# pot               float64
# hemo              float64
# pcv                object
# wc                 object
# rc                 object
# htn                object
# dm                 object
# cad                object
# appet              object
# pe                 object
# ane                object
# classification     object
# dtype: object

# %%
df.columns
# Out:
# Index(['id', 'age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr',
#        'bu', 'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
df.id
# Out:
# 0        0
# 1        1
# 2        2
# 3        3
# 4        4
#       ...
# 395    395
# 396    396
# 397    397
# 398    398
# 399    399
# Name: id, Length: 400, dtype: int64

# %%
df.drop('id',axis = 1,inplace = True)

# %%
df
# Out:
#       age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0    48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 1     7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 2    62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3    48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4    51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
# ..    ...   ...    ...  ...  ...     ...       ...         ...         ...
# 395  55.0  80.0  1.020  0.0  0.0  normal    normal  notpresent  notpresent
# 396  42.0  70.0  1.025  0.0  0.0  normal    normal  notpresent  notpresent
# 397  12.0  80.0  1.020  0.0  0.0  normal    normal  notpresent  notpresent
# 398  17.0  60.0  1.025  0.0  0.0  normal    normal  notpresent  notpresent
# 399  58.0  80.0  1.025  0.0  0.0  normal    normal  notpresent  notpresent
#
# ...

# %%
df.columns = ['age', 'blood_pressure', 'specific_gravity', 'albumin', 'sugar', 'red_blood_cells', 'pus_cell',
              'pus_cell_clumps', 'bacteria', 'blood_glucose_random', 'blood_urea', 'serum_creatinine', 'sodium',
              'potassium', 'haemoglobin', 'packed_cell_volume', 'white_blood_cell_count', 'red_blood_cell_count',
              'hypertension', 'diabetes_mellitus', 'coronary_artery_disease', 'appetite', 'peda_edema',
              'aanemia', 'class']

# %%
df
# Out:
#       age  blood_pressure  specific_gravity  albumin  sugar red_blood_cells  \
# 0    48.0            80.0             1.020      1.0    0.0             NaN
# 1     7.0            50.0             1.020      4.0    0.0             NaN
# 2    62.0            80.0             1.010      2.0    3.0          normal
# 3    48.0            70.0             1.005      4.0    0.0          normal
# 4    51.0            80.0             1.010      2.0    0.0          normal
# ..    ...             ...               ...      ...    ...             ...
# 395  55.0            80.0             1.020      0.0    0.0          normal
# 396  42.0            70.0             1.025      0.0    0.0          normal
# 397  12.0            80.0             1.020      0.0    0.0          normal
# 398  17.0            60.0             1.025      0.0    0.0          normal
# 399  58.0            80.0             1.025      0.0    0.0          normal
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   age                      391 non-null    float64
#  1   blood_pressure           388 non-null    float64
#  2   specific_gravity         353 non-null    float64
#  3   albumin                  354 non-null    float64
#  4   sugar                    351 non-null    float64
#  5   red_blood_cells          248 non-null    object
#  6   pus_cell                 335 non-null    object
#  7   pus_cell_clumps          396 non-null    object
#  8   bacteria                 396 non-null    object
#  9   blood_glucose_random     356 non-null    float64
#  10  blood_urea               381 non-null    float64
#  11  serum_creatinine         383 non-null    float64
#  12  sodium                   313 non-null    float64
#  13  potassium                312 non-null    float64
# ...

# %%
df['packed_cell_volume']
# Out:
# 0      44
# 1      38
# 2      31
# 3      32
# 4      35
#        ..
# 395    47
# 396    54
# 397    49
# 398    51
# 399    53
# Name: packed_cell_volume, Length: 400, dtype: object

# %%
df['packed_cell_volume'].unique()
# Out:
# array(['44', '38', '31', '32', '35', '39', '36', '33', '29', '28', nan,
#        '16', '24', '37', '30', '34', '40', '45', '27', '48', '\t?', '52',
#        '14', '22', '18', '42', '17', '46', '23', '19', '25', '41', '26',
#        '15', '21', '43', '20', '\t43', '47', '9', '49', '50', '53', '51',
#        '54'], dtype=object)

# %%
df['packed_cell_volume'] = pd.to_numeric(df.packed_cell_volume, errors = 'coerce') #This is another way of replacing
#coerce will suppress/ignore the null values

# %%
df['packed_cell_volume'].unique()
# Out:
# array([44., 38., 31., 32., 35., 39., 36., 33., 29., 28., nan, 16., 24.,
#        37., 30., 34., 40., 45., 27., 48., 52., 14., 22., 18., 42., 17.,
#        46., 23., 19., 25., 41., 26., 15., 21., 43., 20., 47.,  9., 49.,
#        50., 53., 51., 54.])

# %%
df['packed_cell_volume']
# Out:
# 0      44.0
# 1      38.0
# 2      31.0
# 3      32.0
# 4      35.0
#        ...
# 395    47.0
# 396    54.0
# 397    49.0
# 398    51.0
# 399    53.0
# Name: packed_cell_volume, Length: 400, dtype: float64

# %%
df['white_blood_cell_count']=df['white_blood_cell_count'].astype(float,errors = 'ignore')

# %%
df['white_blood_cell_count'].unique()
# Out:
# array(['7800', '6000', '7500', '6700', '7300', nan, '6900', '9600',
#        '12100', '4500', '12200', '11000', '3800', '11400', '5300', '9200',
#        '6200', '8300', '8400', '10300', '9800', '9100', '7900', '6400',
#        '8600', '18900', '21600', '4300', '8500', '11300', '7200', '7700',
#        '14600', '6300', '\t6200', '7100', '11800', '9400', '5500', '5800',
#        '13200', '12500', '5600', '7000', '11900', '10400', '10700',
#        '12700', '6800', '6500', '13600', '10200', '9000', '14900', '8200',
#        '15200', '5000', '16300', '12400', '\t8400', '10500', '4200',
#        '4700', '10900', '8100', '9500', '2200', '12800', '11200', '19100',
#        '\t?', '12300', '16700', '2600', '26400', '8800', '7400', '4900',
#        '8000', '12000', '15700', '4100', '5700', '11500', '5400', '10800',
#        '9900', '5200', '5900', '9300', '9700', '5100', '6600'],
#       dtype=object)

# %%
df['white_blood_cell_count'].count()
# Out:
# 295

# %%
df['white_blood_cell_count']=pd.to_numeric(df.white_blood_cell_count , errors = 'coerce')

# %%
df['white_blood_cell_count'].unique()
# Out:
# array([ 7800.,  6000.,  7500.,  6700.,  7300.,    nan,  6900.,  9600.,
#        12100.,  4500., 12200., 11000.,  3800., 11400.,  5300.,  9200.,
#         6200.,  8300.,  8400., 10300.,  9800.,  9100.,  7900.,  6400.,
#         8600., 18900., 21600.,  4300.,  8500., 11300.,  7200.,  7700.,
#        14600.,  6300.,  7100., 11800.,  9400.,  5500.,  5800., 13200.,
#        12500.,  5600.,  7000., 11900., 10400., 10700., 12700.,  6800.,
#         6500., 13600., 10200.,  9000., 14900.,  8200., 15200.,  5000.,
#        16300., 12400., 10500.,  4200.,  4700., 10900.,  8100.,  9500.,
#         2200., 12800., 11200., 19100., 12300., 16700.,  2600., 26400.,
#         8800.,  7400.,  4900.,  8000., 12000., 15700.,  4100.,  5700.,
#        11500.,  5400., 10800.,  9900.,  5200.,  5900.,  9300.,  9700.,
#         5100.,  6600.])

# %%
df['white_blood_cell_count'].count()   #/t? has been dropped out
# Out:
# 294

# %%
df['white_blood_cell_count']
# Out:
# 0      7800.0
# 1      6000.0
# 2      7500.0
# 3      6700.0
# 4      7300.0
#         ...
# 395    6700.0
# 396    7800.0
# 397    6600.0
# 398    7200.0
# 399    6800.0
# Name: white_blood_cell_count, Length: 400, dtype: float64

# %%
categorical_columns = [col for col in df.columns if df[col].dtype ==  'object' ]
numerical_columns = [col for col in df.columns if df[col].dtype !=  'object' ]

# %%
categorical_columns
# Out:
# ['red_blood_cells',
#  'pus_cell',
#  'pus_cell_clumps',
#  'bacteria',
#  'red_blood_cell_count',
#  'hypertension',
#  'diabetes_mellitus',
#  'coronary_artery_disease',
#  'appetite',
#  'peda_edema',
#  'aanemia',
#  'class']

# %%
numerical_columns
# Out:
# ['age',
#  'blood_pressure',
#  'specific_gravity',
#  'albumin',
#  'sugar',
#  'blood_glucose_random',
#  'blood_urea',
#  'serum_creatinine',
#  'sodium',
#  'potassium',
#  'haemoglobin',
#  'packed_cell_volume',
#  'white_blood_cell_count']

# %%
df.columns
# Out:
# Index(['age', 'blood_pressure', 'specific_gravity', 'albumin', 'sugar',
#        'red_blood_cells', 'pus_cell', 'pus_cell_clumps', 'bacteria',
#        'blood_glucose_random', 'blood_urea', 'serum_creatinine', 'sodium',
#        'potassium', 'haemoglobin', 'packed_cell_volume',
#        'white_blood_cell_count', 'red_blood_cell_count', 'hypertension',
#        'diabetes_mellitus', 'coronary_artery_disease', 'appetite',
#        'peda_edema', 'aanemia', 'class'],
#       dtype='object')

# %%
df
# Out:
#       age  blood_pressure  specific_gravity  albumin  sugar red_blood_cells  \
# 0    48.0            80.0             1.020      1.0    0.0             NaN
# 1     7.0            50.0             1.020      4.0    0.0             NaN
# 2    62.0            80.0             1.010      2.0    3.0          normal
# 3    48.0            70.0             1.005      4.0    0.0          normal
# 4    51.0            80.0             1.010      2.0    0.0          normal
# ..    ...             ...               ...      ...    ...             ...
# 395  55.0            80.0             1.020      0.0    0.0          normal
# 396  42.0            70.0             1.025      0.0    0.0          normal
# 397  12.0            80.0             1.020      0.0    0.0          normal
# 398  17.0            60.0             1.025      0.0    0.0          normal
# 399  58.0            80.0             1.025      0.0    0.0          normal
#
# ...

# %%
for col in categorical_columns:
    print(f"{col} has {df[col].unique()}  values.\n ")
# Out:
# red_blood_cells has [nan 'normal' 'abnormal']  values.
#
# pus_cell has ['normal' 'abnormal' nan]  values.
#
# pus_cell_clumps has ['notpresent' 'present' nan]  values.
#
# bacteria has ['notpresent' 'present' nan]  values.
#
# red_blood_cell_count has ['5.2' nan '3.9' '4.6' '4.4' '5' '4.0' '3.7' '3.8' '3.4' '2.6' '2.8' '4.3'
#  '3.2' '3.6' '4' '4.1' '4.9' '2.5' '4.2' '4.5' '3.1' '4.7' '3.5' '6.0'
#  '5.0' '2.1' '5.6' '2.3' '2.9' '2.7' '8.0' '3.3' '3.0' '3' '2.4' '4.8'
#  '\t?' '5.4' '6.1' '6.2' '6.3' '5.1' '5.8' '5.5' '5.3' '6.4' '5.7' '5.9'
#  '6.5']  values.
#
# hypertension has ['yes' 'no' nan]  values.
#
# diabetes_mellitus has ['yes' 'no' ' yes' '\tno' '\tyes' nan]  values.
#
# coronary_artery_disease has ['no' 'yes' '\tno' nan]  values.
#
# appetite has ['good' 'poor' nan]  values.
#
# peda_edema has ['no' 'yes' nan]  values.
#
# aanemia has ['no' 'yes' nan]  values.
#
# class has ['ckd' 'ckd\t' 'notckd']  values.

# %%
df['diabetes_mellitus'] = df['diabetes_mellitus'].replace(to_replace = ' yes' , value = 'yes')

# %%
df['diabetes_mellitus'].replace(to_replace = {'\tno' : 'no', '\tyes': 'yes', ' yes': 'yes'}, inplace = True)
#This just the advanced version of the previous one

# %%
df['coronary_artery_disease'] = df['coronary_artery_disease'].replace(to_replace = '\tno', value = 'no')

# %%
df['class'] = df['class'].replace(to_replace = {'ckd\t' : 'ckd', 'notckd': 'not ckd'})

# %%
df['diabetes_mellitus'].unique()
# Out:
# array(['yes', 'no', nan], dtype=object)

# %%
df['class'].unique()
# Out:
# array(['ckd', 'not ckd'], dtype=object)

# %%
for col in categorical_columns:
    print(f"{col} has {df[col].unique()}  values.\n ")
# Out:
# red_blood_cells has [nan 'normal' 'abnormal']  values.
#
# pus_cell has ['normal' 'abnormal' nan]  values.
#
# pus_cell_clumps has ['notpresent' 'present' nan]  values.
#
# bacteria has ['notpresent' 'present' nan]  values.
#
# red_blood_cell_count has ['5.2' nan '3.9' '4.6' '4.4' '5' '4.0' '3.7' '3.8' '3.4' '2.6' '2.8' '4.3'
#  '3.2' '3.6' '4' '4.1' '4.9' '2.5' '4.2' '4.5' '3.1' '4.7' '3.5' '6.0'
#  '5.0' '2.1' '5.6' '2.3' '2.9' '2.7' '8.0' '3.3' '3.0' '3' '2.4' '4.8'
#  '\t?' '5.4' '6.1' '6.2' '6.3' '5.1' '5.8' '5.5' '5.3' '6.4' '5.7' '5.9'
#  '6.5']  values.
#
# hypertension has ['yes' 'no' nan]  values.
#
# diabetes_mellitus has ['yes' 'no' nan]  values.
#
# coronary_artery_disease has ['no' 'yes' nan]  values.
#
# appetite has ['good' 'poor' nan]  values.
#
# peda_edema has ['no' 'yes' nan]  values.
#
# aanemia has ['no' 'yes' nan]  values.
#
# class has ['ckd' 'not ckd']  values.

# %%
df['class'] = df['class'].map({'ckd':0, 'not ckd': 1})   #ckd :Chronic Kidney Disease
 #not ckd :Not Chronic Kidney Disease

# %%
df['class'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df['age'].unique()
# Out:
# array([48.,  7., 62., 51., 60., 68., 24., 52., 53., 50., 63., 40., 47.,
#        61., 21., 42., 75., 69., nan, 73., 70., 65., 76., 72., 82., 46.,
#        45., 35., 54., 11., 59., 67., 15., 55., 44., 26., 64., 56.,  5.,
#        74., 38., 58., 71., 34., 17., 12., 43., 41., 57.,  8., 39., 66.,
#        81., 14., 27., 83., 30.,  4.,  3.,  6., 32., 80., 49., 90., 78.,
#        19.,  2., 33., 36., 37., 23., 25., 20., 29., 28., 22., 79.])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   age                      391 non-null    float64
#  1   blood_pressure           388 non-null    float64
#  2   specific_gravity         353 non-null    float64
#  3   albumin                  354 non-null    float64
#  4   sugar                    351 non-null    float64
#  5   red_blood_cells          248 non-null    object
#  6   pus_cell                 335 non-null    object
#  7   pus_cell_clumps          396 non-null    object
#  8   bacteria                 396 non-null    object
#  9   blood_glucose_random     356 non-null    float64
#  10  blood_urea               381 non-null    float64
#  11  serum_creatinine         383 non-null    float64
#  12  sodium                   313 non-null    float64
#  13  potassium                312 non-null    float64
# ...

# %%
df.isna()
# Out:
#        age  blood_pressure  specific_gravity  albumin  sugar  red_blood_cells  \
# 0    False           False             False    False  False             True
# 1    False           False             False    False  False             True
# 2    False           False             False    False  False            False
# 3    False           False             False    False  False            False
# 4    False           False             False    False  False            False
# ..     ...             ...               ...      ...    ...              ...
# 395  False           False             False    False  False            False
# 396  False           False             False    False  False            False
# 397  False           False             False    False  False            False
# 398  False           False             False    False  False            False
# 399  False           False             False    False  False            False
#
# ...

# %%
df.isna().sum()    #IT SHOWS ONLY THE NULL DATA'S
# Out:
# age                          9
# blood_pressure              12
# specific_gravity            47
# albumin                     46
# sugar                       49
# red_blood_cells            152
# pus_cell                    65
# pus_cell_clumps              4
# bacteria                     4
# blood_glucose_random        44
# blood_urea                  19
# serum_creatinine            17
# sodium                      87
# potassium                   88
# haemoglobin                 52
# packed_cell_volume          71
# white_blood_cell_count     106
# red_blood_cell_count       130
# hypertension                 2
# diabetes_mellitus            2
# coronary_artery_disease      2
# appetite                     1
# peda_edema                   1
# aanemia                      1
# class                        0
# dtype: int64

# %%
#univariate analysis

# %%
plt.figure(figsize = (6, 4))
sns.histplot(df['age'].dropna(), kde = True, color = 'Orange')
plt.title('Distribution of age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize = (6, 4))
sns.histplot(df['age'], kde = True, color = 'Orange')
plt.title('Distribution of age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
df['age'].unique()
# Out:
# array([48.,  7., 62., 51., 60., 68., 24., 52., 53., 50., 63., 40., 47.,
#        61., 21., 42., 75., 69., nan, 73., 70., 65., 76., 72., 82., 46.,
#        45., 35., 54., 11., 59., 67., 15., 55., 44., 26., 64., 56.,  5.,
#        74., 38., 58., 71., 34., 17., 12., 43., 41., 57.,  8., 39., 66.,
#        81., 14., 27., 83., 30.,  4.,  3.,  6., 32., 80., 49., 90., 78.,
#        19.,  2., 33., 36., 37., 23., 25., 20., 29., 28., 22., 79.])

# %%
df['age'].dropna().unique()
# Out:
# array([48.,  7., 62., 51., 60., 68., 24., 52., 53., 50., 63., 40., 47.,
#        61., 21., 42., 75., 69., 73., 70., 65., 76., 72., 82., 46., 45.,
#        35., 54., 11., 59., 67., 15., 55., 44., 26., 64., 56.,  5., 74.,
#        38., 58., 71., 34., 17., 12., 43., 41., 57.,  8., 39., 66., 81.,
#        14., 27., 83., 30.,  4.,  3.,  6., 32., 80., 49., 90., 78., 19.,
#         2., 33., 36., 37., 23., 25., 20., 29., 28., 22., 79.])

# %%
#insights

#the mean age is around  50
#Most of the people are around 40-60
#70-80 low no of people and 0-20

# %%
df.columns
# Out:
# Index(['age', 'blood_pressure', 'specific_gravity', 'albumin', 'sugar',
#        'red_blood_cells', 'pus_cell', 'pus_cell_clumps', 'bacteria',
#        'blood_glucose_random', 'blood_urea', 'serum_creatinine', 'sodium',
#        'potassium', 'haemoglobin', 'packed_cell_volume',
#        'white_blood_cell_count', 'red_blood_cell_count', 'hypertension',
#        'diabetes_mellitus', 'coronary_artery_disease', 'appetite',
#        'peda_edema', 'aanemia', 'class'],
#       dtype='object')

# %%
df.hypertension.unique()
# Out:
# array(['yes', 'no', nan], dtype=object)

# %%
df['hypertension'].value_counts()
# Out:
# hypertension
# no     251
# yes    147
# Name: count, dtype: int64

# %%
df_temp = df[df['class'] == 0]

# %%
df_temp['hypertension'].value_counts()
# Out:
# hypertension
# yes    147
# no     103
# Name: count, dtype: int64

# %%
#How many people having cronic disease has hypertension

# %%
plt.figure(figsize = (6, 3))
sns.countplot(x = 'hypertension', data =df ,palette = 'viridis')
plt.title('count of hypertension')
plt.xlabel('Hypertension')
plt.ylabel('count')
plt.show()

# %%
#150 have hypertension

# %%
plt.figure(figsize = (6,3))
sns.boxplot(x = 'class', y='blood_urea', data=df,palette = 'magma')
plt.xlabel('Class')
plt.ylabel('Blood urea')
plt.title("Boxplot of blood urea by class")
plt.show()

# %%
df.columns
# Out:
# Index(['age', 'blood_pressure', 'specific_gravity', 'albumin', 'sugar',
#        'red_blood_cells', 'pus_cell', 'pus_cell_clumps', 'bacteria',
#        'blood_glucose_random', 'blood_urea', 'serum_creatinine', 'sodium',
#        'potassium', 'haemoglobin', 'packed_cell_volume',
#        'white_blood_cell_count', 'red_blood_cell_count', 'hypertension',
#        'diabetes_mellitus', 'coronary_artery_disease', 'appetite',
#        'peda_edema', 'aanemia', 'class'],
#       dtype='object')

# %%
plt.figure(figsize = (6,3))
sns.violinplot(x = 'class', y='serum_creatinine', data=df,palette = 'inferno')
plt.xlabel('Class')
plt.ylabel('Blood urea')
plt.title("Violinplot of blood urea by class")
plt.show()

# %%
sns.countplot(x='aanemia', data=df,palette = 'plasma')
# Out:
# <Axes: xlabel='aanemia', ylabel='count'>

# %%
df.columns
# Out:
# Index(['age', 'blood_pressure', 'specific_gravity', 'albumin', 'sugar',
#        'red_blood_cells', 'pus_cell', 'pus_cell_clumps', 'bacteria',
#        'blood_glucose_random', 'blood_urea', 'serum_creatinine', 'sodium',
#        'potassium', 'haemoglobin', 'packed_cell_volume',
#        'white_blood_cell_count', 'red_blood_cell_count', 'hypertension',
#        'diabetes_mellitus', 'coronary_artery_disease', 'appetite',
#        'peda_edema', 'aanemia', 'class'],
#       dtype='object')

# %%
df.appetite
# Out:
# 0      good
# 1      good
# 2      poor
# 3      poor
# 4      good
#        ...
# 395    good
# 396    good
# 397    good
# 398    good
# 399    good
# Name: appetite, Length: 400, dtype: object

# %%
df['appetite'].value_counts().plot.pie(autopct='%1.1f%%', colors=['lightcoral', 'lightgreen'], explode=(0, 0.1),startangle =90, shadow =True)
# Out:
# <Axes: ylabel='count'>

# %%
df['appetite'].value_counts().plot.pie(autopct='%1.1f%%',colors=['lightcoral', 'lightgreen'], explode=(0.0, 0.5), shadow =True)
# Out:
# <Axes: ylabel='count'>

# %%
#79.4% has good appetite

# %%
df['appetite'].value_counts().plot.pie(autopct='%1.1f%%', colors=['lightcoral', 'lightgreen'], wedgeprops = dict(width=0.3)  ,startangle =90, shadow =True)
# Out:
# <Axes: ylabel='count'>

# %%
#if we want to analyse - how many ppl having cronic disease and hypertension with poor appetite?

# %%
df.columns
# Out:
# Index(['age', 'blood_pressure', 'specific_gravity', 'albumin', 'sugar',
#        'red_blood_cells', 'pus_cell', 'pus_cell_clumps', 'bacteria',
#        'blood_glucose_random', 'blood_urea', 'serum_creatinine', 'sodium',
#        'potassium', 'haemoglobin', 'packed_cell_volume',
#        'white_blood_cell_count', 'red_blood_cell_count', 'hypertension',
#        'diabetes_mellitus', 'coronary_artery_disease', 'appetite',
#        'peda_edema', 'aanemia', 'class'],
#       dtype='object')

# %%
plt.figure(figsize = (6,3))
sns.countplot(x = 'peda_edema', data=df,palette = 'cividis')
# Out:
# <Axes: xlabel='peda_edema', ylabel='count'>

# %%
plt.figure(figsize = (20, 10))
plotnumber = 1


for col in numerical_columns:
    if plotnumber <= 15:
        ax = plt.subplot(3, 5, plotnumber)
        sns.distplot(df[col])
        plt.xlabel(col)
    plotnumber += 1
    
plt.tight_layout()
plt.show()

# %%
def kde(col):
    grid = sns.FacetGrid(df, hue = "class", height =6, aspect=2)
    grid.map(sns.kdeplot, col)
    grid.add_legend()

# %%
df['red_blood_cell_count'].unique()
# Out:
# array(['5.2', nan, '3.9', '4.6', '4.4', '5', '4.0', '3.7', '3.8', '3.4',
#        '2.6', '2.8', '4.3', '3.2', '3.6', '4', '4.1', '4.9', '2.5', '4.2',
#        '4.5', '3.1', '4.7', '3.5', '6.0', '5.0', '2.1', '5.6', '2.3',
#        '2.9', '2.7', '8.0', '3.3', '3.0', '3', '2.4', '4.8', '\t?', '5.4',
#        '6.1', '6.2', '6.3', '5.1', '5.8', '5.5', '5.3', '6.4', '5.7',
#        '5.9', '6.5'], dtype=object)

# %%
df['red_blood_cell_count'] = df['red_blood_cell_count'].replace(to_replace ='\t?' , value = '')

# %%
df['red_blood_cell_count'].unique()
# Out:
# array(['5.2', nan, '3.9', '4.6', '4.4', '5', '4.0', '3.7', '3.8', '3.4',
#        '2.6', '2.8', '4.3', '3.2', '3.6', '4', '4.1', '4.9', '2.5', '4.2',
#        '4.5', '3.1', '4.7', '3.5', '6.0', '5.0', '2.1', '5.6', '2.3',
#        '2.9', '2.7', '8.0', '3.3', '3.0', '3', '2.4', '4.8', '', '5.4',
#        '6.1', '6.2', '6.3', '5.1', '5.8', '5.5', '5.3', '6.4', '5.7',
#        '5.9', '6.5'], dtype=object)

# %%
df['white_blood_cell_count'].unique()
# Out:
# array([ 7800.,  6000.,  7500.,  6700.,  7300.,    nan,  6900.,  9600.,
#        12100.,  4500., 12200., 11000.,  3800., 11400.,  5300.,  9200.,
#         6200.,  8300.,  8400., 10300.,  9800.,  9100.,  7900.,  6400.,
#         8600., 18900., 21600.,  4300.,  8500., 11300.,  7200.,  7700.,
#        14600.,  6300.,  7100., 11800.,  9400.,  5500.,  5800., 13200.,
#        12500.,  5600.,  7000., 11900., 10400., 10700., 12700.,  6800.,
#         6500., 13600., 10200.,  9000., 14900.,  8200., 15200.,  5000.,
#        16300., 12400., 10500.,  4200.,  4700., 10900.,  8100.,  9500.,
#         2200., 12800., 11200., 19100., 12300., 16700.,  2600., 26400.,
#         8800.,  7400.,  4900.,  8000., 12000., 15700.,  4100.,  5700.,
#        11500.,  5400., 10800.,  9900.,  5200.,  5900.,  9300.,  9700.,
#         5100.,  6600.])

# %%
kde('red_blood_cell_count')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 kde('red_blood_cell_count')
#
# Cell In[76], line 3, in kde(col)
#       1 def kde(col):
#       2     grid = sns.FacetGrid(df, hue = "class", height =6, aspect=2)
# ----> 3     grid.map(sns.kdeplot, col)
#       4     grid.add_legend()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\axisgrid.py:758, in FacetGrid.map(self, func, *args, **kwargs)
#     755         plot_args = [v.values for v in plot_args]
#     757     # Draw the plot
# --> 758     self._facet_plot(func, ax, plot_args, kwargs)
#     760 # Finalize the annotations and layout
#     761 self._finalize_grid(args[:2])
#
# ...

# %%
kde('white_blood_cell_count')

# %%
kde('haemoglobin')

# %%
def violin(col):
    fig = px.violin(df, y=col, x='class', box =True, template = 'plotly_dark')
    return fig.show()

# %%
violin('haemoglobin')

# %%
#insights >> outliers are present, 3.1 and 4.8, 16.1 for class 0

violin('packed_cell_volume')

# %%
violin('specific_gravity')

# %%
#bivariate


sns.scatterplot(x = 'age', y = 'blood_pressure', data = df, hue='class')
# Out:
# <Axes: xlabel='age', ylabel='blood_pressure'>

# %%
#insight>> high bp causes chronic disease

# %%
df.columns
# Out:
# Index(['age', 'blood_pressure', 'specific_gravity', 'albumin', 'sugar',
#        'red_blood_cells', 'pus_cell', 'pus_cell_clumps', 'bacteria',
#        'blood_glucose_random', 'blood_urea', 'serum_creatinine', 'sodium',
#        'potassium', 'haemoglobin', 'packed_cell_volume',
#        'white_blood_cell_count', 'red_blood_cell_count', 'hypertension',
#        'diabetes_mellitus', 'coronary_artery_disease', 'appetite',
#        'peda_edema', 'aanemia', 'class'],
#       dtype='object')

# %%
df['diabetes_mellitus'].unique()
# Out:
# array(['yes', 'no', nan], dtype=object)

# %%
df['hypertension'].unique()
# Out:
# array(['yes', 'no', nan], dtype=object)

# %%
diabetes_hypertension = pd.crosstab(df['diabetes_mellitus'], df['hypertension'])
diabetes_hypertension.plot(kind = 'bar', stacked = True, color = ['#6DA7DE', '#FF9A8B'], figsize = (5, 4))

plt.xlabel("diabetes_mellitus ")
plt.ylabel("count")
plt.legend(title="hypertension")
plt.title("stacked diabetes_mellitus and hypertension")
plt.show()

# %%
diabetes_hypertension = pd.crosstab(df['diabetes_mellitus'], df['hypertension'])
diabetes_hypertension
# Out:
# hypertension        no  yes
# diabetes_mellitus
# no                 220   41
# yes                 31  106

# %%
def scatter(col1, col2):
    fig = px.scatter(df, x = col1, y=col2, color = "class", template = "plotly_dark")
    return fig.show()

# %%
scatter('haemoglobin', 'packed_cell_volume')

# %%
#multivariable analysis

selected_coulmns = ['age', 'blood_pressure', 'haemoglobin', 'class']
sns.pairplot(df[selected_coulmns], hue ='class', palette = 'husl')

# %%
df[selected_coulmns].corr()

sns.heatmap(df[selected_coulmns].corr(), annot = True, cmap = "coolwarm", linewidth = .5)
# Out:
# <Axes: >

# %%
import plotly.graph_objects as go

heatmap_data = df[selected_coulmns].corr()

fig = go.Figure(data=go.Heatmap(z=heatmap_data.values,
                                x=heatmap_data.columns,
                                y=heatmap_data.index,
                                colorscale='Viridis'))

fig.update_layout(title='Interactive Heatmap of Correlation Matrix')
fig.show()

# %%
fig = px.scatter_3d(df, x='age', y='blood_pressure', z='serum_creatinine', color='haemoglobin',
                    title='3D Scatter plot with Color Gradient')
fig.show()
